# %%
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv

load_dotenv()

embedding = OpenAIEmbeddings(model='text-embedding-3-large',dimensions=32)# size is less than cost is low context meaning is also less
result=embedding.embed_query('delhi is the capital of india')

print(str(result))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 6
#       2 from dotenv import load_dotenv
#       4 load_dotenv()
# ----> 6 embedding = OpenAIEmbeddings(model='text-embedding-3-large',dimensions=32)# size is less than cost is low context meaning is also less
#       7 result=embedding.embed_query('delhi is the capital of india')
#       9 print(str(result))
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_openai\embeddings\base.py:448, in OpenAIEmbeddings.validate_environment(self)
#     443         self.http_async_client = httpx.AsyncClient(proxy=self.openai_proxy)
#     444     async_specific = {
#     445         "http_client": self.http_async_client,
#     446         "api_key": async_api_key_value,
#     447     }
# --> 448     self.async_client = openai.AsyncOpenAI(
#     449         **client_params,
#     450         **async_specific,  # type: ignore[arg-type]
#     451     ).embeddings
#     452 return self
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_client.py:587, in AsyncOpenAI.__init__(self, api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     585     api_key = os.environ.get("OPENAI_API_KEY")
#     586 if api_key is None:
# --> 587     raise OpenAIError(
#     588         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     589     )
#     590 if callable(api_key):
#     591     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
