# %%
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv

load_dotenv()

embedding = OpenAIEmbeddings(model='text-embedding-3-large',dimensions=32)# size is less than cost is low context meaning is also less
result=embedding.embed_documents('delhi is the capital of india')

print(str(result))
