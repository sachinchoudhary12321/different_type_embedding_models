# %%
pip install langchain_huggingface
# Out:
# ...
#   Using cached langchain_huggingface-1.2.1-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# ...
#   Using cached fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached langchain_huggingface-1.2.1-py3-none-any.whl (30 kB)
# ...
#    ---------------------------------------- 0.0/642.6 kB ? eta -:--:--
#    -------------------------------- ------- 524.3/642.6 kB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 642.6/642.6 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:68, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      67 try:
# ---> 68     import sentence_transformers  # type: ignore[import]
#      69 except ImportError as exc:
#
# ModuleNotFoundError: No module named 'sentence_transformers'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 6
#       2 from dotenv import load_dotenv
#       4 load_dotenv()
# ----> 6 embeddings = HuggingFaceEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
#       8 text = 'delhi is capiatl of india'
#      11 vector = embeddings.embed_query(text)
#
# ...
